# %%
import sys

sys.path.append("review_object_detection_metrics/")

# %%
import pandas as pd
import pickle
import numpy as np

# %%
with open("output/pascal_rec.pickle", "rb") as fp:
    result = pickle.load(fp)

# %%
result.keys()
# Out:
# dict_keys(['precision', 'recall', 'AP', 'interpolated precision', 'interpolated recall', 'total positives', 'total TP', 'total FP', 'method', 'iou', 'table'])

# %%
result['table']
# Out:
#                    image confidence  TP  FP  acc TP  acc FP  precision  \
# 0     f99140e2c7d9_image     95.66%   1   0     1.0     0.0   1.000000
# 1     2446e23969e6_image     95.42%   1   0     2.0     0.0   1.000000
# 2     c8e548bba5f8_image     95.15%   1   0     3.0     0.0   1.000000
# 3     b812e01902fa_image     94.78%   1   0     4.0     0.0   1.000000
# 4     eb255becb30a_image     94.74%   1   0     5.0     0.0   1.000000
# ...                  ...        ...  ..  ..     ...     ...        ...
# 1655  7d622deec073_image     45.21%   0   1   939.0   717.0   0.567029
# 1656  bf670c1f4aa6_image     45.19%   1   0   940.0   717.0   0.567290
# 1657  4ab9f6b4684d_image     45.16%   0   1   940.0   718.0   0.566948
# 1658  d4bce67cb700_image     45.08%   0   1   940.0   719.0   0.566606
# 1659  a464a0534b1e_image     45.07%   0   1   940.0   720.0   0.566265
#
#         recall
# 0     0.000637
# 1     0.001273
# 2     0.001910
# 3     0.002546
# 4     0.003183
# ...        ...
# ...

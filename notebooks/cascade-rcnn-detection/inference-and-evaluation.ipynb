# %%
sys.path.append("../../")

# %%
import sys
sys.path.insert(0, "./mmdetection")

import os
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())

# Check MMDetection installation
from mmdet.apis import set_random_seed

# Imports
from mmdet.apis import set_random_seed

import mmcv
from mmdet.models import build_detector
from mmcv.runner import load_checkpoint
from mmcv.parallel import MMDataParallel
from mmdet.datasets import build_dataloader, build_dataset
from mmdet.apis import single_gpu_test
from mmdet.apis import init_detector, inference_detector, show_result_pyplot

import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import cv2
import json
import random
import numpy as np
# Out:
# 1.12.0+cu113 True
# 11.3
# GCC 9.3

# %%
global_seed = 111

def set_seed(seed=global_seed):
    """Sets the random seeds."""
    set_random_seed(seed, deterministic=False)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    
set_seed()

# %%
from mmcv import Config

cfg_path = f'../../backend/models/configs/cascade_rcnn_x101_32x4d_fpn_1x_coco.py'
model_checkpoint = "../../backend/models/weights/cascade_rcnn_best_epoch.pth"

print("Loading weights from:", model_checkpoint)
cfg = Config.fromfile(cfg_path)
model = init_detector(cfg, model_checkpoint, device='cuda:0')
# Out:
# Loading weights from: ../../backend/models/weights/cascade_rcnn_best_epoch.pth
# load checkpoint from local path: ../../backend/models/weights/cascade_rcnn_best_epoch.pth
# /workspace/mmdetection/mmdet/apis/inference.py:51: UserWarning: Class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn('Class names are not saved in the checkpoint\'s '

# %%
def draw_bbox(image,
              box,
              label,
              color,
              label_size = 0.5,
              alpha_box = 0.3,
              alpha_label = 0.6):
    
    overlay_bbox = image.copy()
    overlay_label = image.copy()
    output = image.copy()

    text_width, text_height = cv2.getTextSize(label.upper(),
                                              cv2.FONT_HERSHEY_SIMPLEX, label_size, 1)[0]
    cv2.rectangle(overlay_bbox, (box[0], box[1]), (box[2], box[3]),
                  color, -1)
    cv2.addWeighted(overlay_bbox, alpha_box, output, 1-alpha_box, 0, output)
    
    cv2.rectangle(overlay_label, (box[0], box[1]-7-text_height),
                  (box[0]+text_width+2, box[1]), (0, 0, 0), -1)
    cv2.addWeighted(overlay_label, alpha_label, output, 1-alpha_label, 0, output)
    output = cv2.rectangle(output, (box[0], box[1]), (box[2], box[3]),
                           color, 2)
    cv2.putText(output, label.upper(), (box[0], box[1]-5),
            cv2.FONT_HERSHEY_SIMPLEX, label_size, (255, 255, 255), 1, cv2.LINE_AA)
    return output

# %%
with open("../../dataset/covid19-coco-512-GroupKFold/val_annotations_fold0.json") as f:
    val_ann = json.load(f)
    

df_annotations = pd.read_csv('../../dataset/resized-512/df_train_processed_meta.csv')
df_annotations = df_annotations.rename(columns={"width":"dim0", 'height':"dim1"})

new_size = (512, 512)
imgs_path = "../../dataset/resized-512/train"
threshold = 0.45



results_list = []

# %%
df_annotations.head()
# Out:
#                    id StudyInstanceUID     folder_id      study_id  dim0  \
# 0  000a312787f2_image     5776db0cec75  81456c9c5423  5776db0cec75  3488
# 1  000a312787f2_image     5776db0cec75  81456c9c5423  5776db0cec75  3488
# 2  0012ff7358bc_image     9d514ce429a7  22897cd1daa0  9d514ce429a7  2544
# 3  0012ff7358bc_image     9d514ce429a7  22897cd1daa0  9d514ce429a7  2544
# 4  001398f4ff4f_image     28dddc8559b2  4d47bc042ee6  28dddc8559b2  3520
#
#    dim1  xmin  ymin  xmax  ymax
# 0  4256    95    85   218   367
# 1  4256   270    87   402   345
# 2  3056   113    40   259   241
# 3  3056   300    81   404   323
# 4  4280   326   317   440   405

# %%
from rebox import BBox
from rebox.formats import coco, pascal


annotations = {}
for item in val_ann["annotations"]:
    if item["image_id"] in imagepaths.keys():
        bbox = BBox(item["bbox"], coco).as_format(pascal).value.tolist()
        try:
            annotations[item["image_id"]].append(bbox)
        except KeyError:
            annotations[item["image_id"]] = [bbox]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_365/1254475409.py in <module>
#       5 annotations = {}
#       6 for item in val_ann["annotations"]:
# ----> 7     if item["image_id"] in imagepaths.keys():
#       8         bbox = BBox(item["bbox"], coco).as_format(pascal).value.tolist()
#       9         try:
#
# NameError: name 'imagepaths' is not defined

# %%
from rebox import BBox
from rebox.formats import coco, pascal


imagepaths = {item["id"]:item['file_name'] for item in val_ann['images'] if item['id'] in [513, 278, 518, 304, 794, 377]} 



annotations = {}
for item in val_ann["annotations"]:
    if item["image_id"] in imagepaths.keys():
        bbox = BBox(item["bbox"], coco).as_format(pascal).value.tolist()
        try:
            annotations[item["image_id"]].append(bbox)
        except KeyError:
            annotations[item["image_id"]] = [bbox]


fig, axes = plt.subplots(2,3, figsize=(14,10))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
axes = axes.ravel()


for idx, (image_id, filename)  in enumerate(imagepaths.items()):
    img_path = os.path.join(imgs_path, filename)
    img = cv2.imread(img_path)
    result = inference_detector(model, img_path)
    results_filtered = result[0][result[0][:, 4]>threshold]
    bboxes = results_filtered[:, :4]
    scores = results_filtered[:, 4] 
    results_list.append(result[0])
    
    for box in bboxes:
        img = draw_bbox(img, list(np.int_(box)), "Model Detected",
                        (255, 243, 0))
    
    # gt_bboxes = scale_bbox(512, df_annotations[df_annotations["id"] == filename.replace(".png", "")].head(1), annotations[image_id])
    gt_bboxes = annotations[image_id]
    for gt_box in gt_bboxes:
        img = draw_bbox(img, list(np.int_(gt_box)), "Ground Truth",
                        (255, 0, 243))
    # print(gt_bboxes)

    axes[idx].imshow(img, cmap='gray')
    # axes[idx].set_title(img_id, size=18, pad=30)
    axes[idx].set_xticklabels([])
    axes[idx].set_yticklabels([])

plt.savefig("model_detections.png", dpi=350)
# Out:
# /workspace/mmdetection/mmdet/datasets/utils.py:70: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   'data pipeline in your config file.', UserWarning)

# %%
id_set = list(set(i["id"] for i in val_ann['images']))

# %%
from rebox import BBox
from rebox.formats import coco, pascal

random.shuffle(id_set)

imagepaths = {item["id"]:item['file_name'] for item in val_ann['images'] if item['id'] in id_set[:6]} 



annotations = {}
for item in val_ann["annotations"]:
    if item["image_id"] in imagepaths.keys():
        bbox = BBox(item["bbox"], coco).as_format(pascal).value.tolist()
        try:
            annotations[item["image_id"]].append(bbox)
        except KeyError:
            annotations[item["image_id"]] = [bbox]


fig, axes = plt.subplots(2,3, figsize=(14,10))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
axes = axes.ravel()


for idx, (image_id, filename)  in enumerate(imagepaths.items()):
    img_path = os.path.join(imgs_path, filename)
    img = cv2.imread(img_path)
    
    gt_bboxes = annotations[image_id]
    for gt_box in gt_bboxes:
        img = draw_bbox(img, list(np.int_(gt_box)), "Covid Abnormality",
                        (255, 0, 243))
    # print(gt_bboxes)

    axes[idx].imshow(img, cmap='gray')
    # axes[idx].set_title(img_id, size=18, pad=30)
    axes[idx].set_xticklabels([])
    axes[idx].set_yticklabels([])

plt.savefig("dataset_samples.png", dpi=350)

# %%
os.chdir("../../backend")

# %%
sys.path.append(".")

# %%
from inference.covid_classification import condition_classifer

# %%
imgs_path = "../dataset/resized-512/train"

# %%
from PIL import ImageColor

# %%
color_map = {
    'Negative' : ImageColor.getrgb("#471a1a"),
    'Typical Appearance' : ImageColor.getrgb("#f15759"),
    'Indeterminate' : ImageColor.getrgb("#d4f157"),
    'Atypical' : ImageColor.getrgb("#5797f1")
}

# %%
color_map
# Out:
# {'Negative': (71, 26, 26),
#  'Typical Appearance': (241, 87, 89),
#  'Indeterminate': (212, 241, 87),
#  'Atypical': (87, 151, 241)}

# %%
from rebox import BBox
from rebox.formats import coco, pascal


imagepaths = {item["id"]:item['file_name'] for item in val_ann['images'] if item['id'] in [523, 269, 68, 324, 504, 297]} 



annotations = {}
for item in val_ann["annotations"]:
    if item["image_id"] in imagepaths.keys():
        bbox = BBox(item["bbox"], coco).as_format(pascal).value.tolist()
        try:
            annotations[item["image_id"]].append(bbox)
        except KeyError:
            annotations[item["image_id"]] = [bbox]


fig, axes = plt.subplots(2,3, figsize=(14,10))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
axes = axes.ravel()


for idx, (image_id, filename)  in enumerate(imagepaths.items()):
    img_path = os.path.join(imgs_path, filename)
    img = cv2.imread(img_path)
    result = inference_detector(model, img_path)
    condition = condition_classifer.inference(img)
    results_filtered = result[0][result[0][:, 4]>threshold]
    bboxes = results_filtered[:, :4]
    scores = results_filtered[:, 4] 
    results_list.append(result[0])
    
    for box in bboxes:
        img = draw_bbox(img, list(np.int_(box)), condition[0],
                        color_map[condition[0]])
    
    # gt_bboxes = scale_bbox(512, df_annotations[df_annotations["id"] == filename.replace(".png", "")].head(1), annotations[image_id])
    gt_bboxes = annotations[image_id]
    # for gt_box in gt_bboxes:
    #     img = draw_bbox(img, list(np.int_(gt_box)), "Ground Truth",
    #                     (255, 0, 243))
    # print(gt_bboxes)

    axes[idx].imshow(img, cmap='gray')
    # axes[idx].set_title(img_id, size=18, pad=30)
    axes[idx].set_xticklabels([])
    axes[idx].set_yticklabels([])

plt.savefig("model_detections.png", dpi=350)
# Out:
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step

# %%
513, 278, 518, 304, 794, 377

# %%
imagepaths
# Out:
# {183: '35f3e874a4d5_image.png',
#  794: 'ece4e66cb011_image.png',
#  302: '5ce2be1781f6_image.png',
#  377: '736238adb87c_image.png',
#  812: 'f24100b16cb6_image.png',
#  205: '3d9c95938f42_image.png'}

# %%
len(val_ann["images"])
# Out:
# 858

# %%
val_ann["annotations"][8]
# Out:
# {'id': 8,
#  'image_id': 4,
#  'category_id': 0,
#  'area': 17702,
#  'bbox': [346, 132, 106, 167],
#  'iscrowd': 0}

# %%
new_size = (512, 512)
imgs_path = "./dataset/resized-512/train"
threshold = 0.45

detections = []
idx = 0

for image in val_ann["images"]:
    img_path = os.path.join(imgs_path, image['file_name'])
    img = cv2.imread(img_path)
    result = inference_detector(model, img_path)
    results_filtered = result[0][result[0][:, 4]>threshold]
    bboxes = results_filtered[:, :4]
    scores = results_filtered[:, 4]

    for bbox, score in zip(bboxes, scores):
        bbox = BBox(bbox, pascal).as_format(coco).value
        detection = {
            "id": idx,
            "area": bbox[2] * bbox[3],
            "image_id": image["id"],
            "bbox": bbox.astype(np.int32).tolist() ,
            "iscrowd": 0,
            "score": float(score),
            "category_id" : 0
        }
        detections.append(detection)
        idx += 1

# %%
test_det = {
    "images": val_ann["images"],
    "annotations": detections,
    "categories":val_ann["categories"]
}

# %%
len(test_det["annotations"])
# Out:
# 1660

# %%
test_det["annotations"][0]
# Out:
# {'id': 0,
#  'area': 17105.94,
#  'image_id': 0,
#  'bbox': [388, 145, 89, 191],
#  'iscrowd': 0,
#  'score': 0.7773832082748413,
#  'category_id': 0}

# %%
class JSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.float32):
            return float(obj)
        return json.JSONEncoder.default(self, obj)

with open("output/covid-test-det/covid-19-test-det.json", "w") as fp:
    json.dump(test_det, fp, cls=JSONEncoder)

with open("output/covid-test-gts/covid-19-test-gt.json", "w") as fp:
    json.dump(val_ann, fp, cls=JSONEncoder)

# %% [markdown]
# # Result
#
# ```
# COCO METRICS:
# AP: 0.1506856500798415
# AP50: 0.4565885062438053
# AP75: 0.058548339165218
# APsmall: 0.0
# APmedium: 0.0368959715563841
# APlarge: 0.18093391873910716
# AR1: 0.13303628262253342
# AR10: 0.23863781031190326
# AR100: 0.23863781031190326
# ARsmall: 0.0
# ARmedium: 0.048881789137380185
# ARlarge: 0.2879103282626101
#
# PASCAL METRIC (AP per class)
# Covid_Abnormality: 0.5201428573519917
#
# PASCAL METRIC (mAP)
# mAP: 0.5201428573519917
# ```
